# %% [markdown]
# - https://nbviewer.jupyter.org/github/xflr6/graphviz/blob/master/examples/notebook.ipynb
# - https://graphviz.readthedocs.io/en/stable/manual.html#jupyter-notebooks

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files\Graphviz\bin'

from graphviz import Digraph
dot = Digraph(comment='NBA Predict')
dot.node('D', 'D Dati2019-2020')
dot.node('R', 'R RF Model')
dot.node('A', 'D DatiAvg')
dot.node('C', 'C Calendario')
dot.node('S', 'S Calendario+Stats')
dot.node('P', 'P Prediction')
dot.edges(['DR','DA','CS','AS','SP','RP'])

dot

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files\Graphviz\bin'

from graphviz import Digraph
dot = Digraph(comment='The Round Table')
dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')
dot.node('G', 'Geppo il gobbo')
dot.edges(['AB', 'AL','LG'])
dot.edge('B', 'L', constraint='false')

dot

# %%
ps = Digraph(name='pet-shop', node_attr={'shape': 'plaintext'})
ps.node('parrot')
ps.node('dead')
ps.edge('parrot', 'dead')
ps.graph_attr['rankdir'] = 'LR'
ps.edge_attr.update(arrowhead='vee', arrowsize='2')
ps

# %%
from graphviz import Source

src = Source('digraph "the holy hand grenade" { rankdir=LR; 1 -> 2 -> 3 -> lob }')
src

# %%
from graphviz import Digraph

from graphviz import Digraph

s = Digraph('structs', filename='structs_revisited.gv',
            node_attr={'shape': 'record'})

s.node('struct1', '<f0> left|<f1> middle|<f2> right')
s.node('struct2', '<f0> one|<f1> two')
s.node('struct3', r'hello\nworld |{ b |{c|<here> d|e}| f}| g | h')

s.edges([('struct1:f1', 'struct2:f0'), ('struct1:f2', 'struct3:here')])

s

# %%
from graphviz import Digraph

u = Digraph('unix', filename='unix.gv',node_attr={'color': 'lightblue2', 'style': 'filled'})
u.attr(size='6,6')

u.edge('5th Edition', '6th Edition')
u.edge('5th Edition', 'PWB 1.0')
u.edge('6th Edition', 'LSX')
u.edge('6th Edition', '1 BSD')
u.edge('6th Edition', 'Mini Unix')
