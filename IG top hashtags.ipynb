# %% [markdown]
# ## OK creates hashtag string

# %%
import pandas as pd
import requests

tagslist = ["psychedelic"]
#tagslist = ["girl","illustrator","portrait","vector","digital"]

# hashtaglist = pd.DataFrame
hashtaglist = pd.DataFrame(columns = ['Hashtag', 'Posts'])

for word in tagslist:
    print(word)
    url  = 'http://best-hashtags.com/hashtag/' + word
    url
    r = requests.get(url)
    df_list = pd.read_html(r.text) # this parses all the tables in webpages to a list
    tmp = df_list[0].to_numpy()
    print(tmp)
    hashtaglist= hashtaglist.append(df_list[0], ignore_index=True)
    
hashtaglist=hashtaglist.sort_values(by='Posts', ascending=False)

arr = hashtaglist.head(30)["Hashtag"].to_numpy()
arr
' '.join(map(str, arr))
# Out:
# psychedelic
# [[1 '#psychedelicart' 3698078]
#  [2 '#psychedelics' 949759]
#  [3 '#psychedelicrock' 600189]
#  [4 '#psychedelictrance' 361194]
#  [5 '#psychedelicmusic' 210129]
#  [6 '#psychedelicartist' 205805]
#  [7 '#psychedelicsociety' 136823]
#  [8 '#psychedelicmoods' 120576]
#  [9 '#psychedelicphotos' 84258]
#  [10 '#psychedelica' 58854]
#  [11 '#psychedelicatessen' 54259]
#  [12 '#psychedelicartwork' 46393]
#  [13 '#psychedelicfurs' 34204]
#  [14 '#psychedelicpop' 29793]
#  [15 '#psychedelicartsoundandlightexperience' 28292]
#  [16 '#psychedelictattoo' 28213]
#  [17 '#psychedelicexperience' 26800]
#  [18 '#psychedelicphotography' 23311]
#  [19 '#psychedelicvibes' 20771]
#  [20 '#psychedeliclife' 19187]]
# ...

# %%
arr = hashtaglist.head(50)["Hashtag"].to_numpy()
arr
' '.join(map(str, arr))
# Out:
# '#digitalart #digitalmarketing #digitaldrawing #digitalpainting #digitalillustration #moonlight #digitalartist #digitalinfluencer #digitalartwork #hunterxhunter #digitalnomad #digitalphotography #shapes #digitalsketch #moonchild #moonstone #digitalmarketingagency #digitaldesign #digitalcollage #digitalagency #hunters #digitalmarketingtips #moonshine #moonwalker #moonlovers #digitalportrait #digitalprinting #digitalmedia #moonbin #digitalprint #moonphotography #moonrise #huntervalley #moonwalk #moonbyul #hunterjumper #mooncake #moonwalkers #moonlightbae #hunterrowland #moonrock #moonphases #shapewear #moontattoo #moonrocks #shapeofyou #moonchaewon #hunterxhunteredit #hunterboots #hunterhayes'

# %%
import seaborn as sns
import matplotlib.pyplot as plt\

sns.set(rc={'figure.figsize':(12,9)})
ax = sns.barplot(y='Hashtag', x='Posts', data=hashtaglist.head(30))
plt.show()

# %%
sentence = '#halloweenparty #halloween2021 #halloweenfun #halloweentime #halloweencostumes #halloweenart #halloweendecorations #halloweeniscoming #thisishalloween  #splatoon #splatter #splatoonart #splatterpaint #splatfest #splatoonfanart #splatterart #splats #horrormovies #horrorfan #horrorart #horrormovie #horrorfilm #horroraddict#Inktober #Inktober2021 #Inktober2021SPLAT #fabertelart #SPLAT'
sentence.count('#')
# Out:
# 28

# %%
hashtaglist.head(30)
# Out:
#                       Hashtag     Posts     #
# 80                 #dailylook  32849798   1.0
# 81                #dailymemes  18594072   2.0
# 82                  #dailyart   7712440   3.0
# 83               #dailyquotes   6081974   4.0
# 0                   #tomatoes   5522683   1.0
# 84             #dailyfoodfeed   4863280   5.0
# 85                #dailyphoto   4850489   6.0
# 86                #dailyfluff   4669781   7.0
# 87          #dailyinspiration   4100006   8.0
# 88           #dailymotivation   4067954   9.0
# 89                  #dailydog   3787908  10.0
# 90                 #dailylife   3778334  11.0
# 100               #humornegro   3450695   1.0
# 20   #illustratorsoninstagram   3415933   1.0
# 91               #dailybarker   3034109  12.0
# 92                #dailywatch   2957760  13.0
# 93                 #dailypost   2948894  14.0
# 94               #dailysketch   2890458  15.0
# 95            #dailyparenting   2809544  16.0
# ...

# %% [raw]
# https://www.thepresentfinder.co.uk/blog/60-bad-dad-jokes_73891843.htm

# %% [markdown]
# ## TEST ONGOING

# %%
word = 'pokemon'
httppath = 'http://best-hashtags.com/hashtag/' + word
httppath
# Out:
# 'http://best-hashtags.com/hashtag/pokemon'

# %%
"""
Created on Mon Jun  3 11:18:17 2019
Logs to Istagram
"""
#installare https://chromedriver.storage.googleapis.com/index.html?path=74.0.3729.6/


import os 
import sys
import time
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

print(os.getcwd())
browser = webdriver.Chrome(r"C:\Users\fabio\Desktop\PYHTON\Selenium\chromedriver.exe")

browser.implicitly_wait(5)

word = 'pokemon'
httppath = 'http://best-hashtags.com/hashtag/' + word
browser.get('http://best-hashtags.com/hashtag/pokemon/')

okcookies_button = browser.find_element_by_xpath("/html/body/div[2]/div/div/div/div[2]/button[1]")
okcookies_button.click()
# Out:
# C:\Users\fabio\Desktop\PYHTON
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-2-913065a07f7d> in <module>
#      20 browser.get('https://www.instagram.com/')
#      21
# ---> 22 okcookies_button = browser.find_element_by_xpath("/html/body/div[2]/div/div/div/div[2]/button[1]")
#      23 okcookies_button.click()
#
# c:\users\fabio\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# c:\users\fabio\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
from selenium import webdriver
import time
from random import seed
from random import randint

class InstaBot:
    def __init__(self, username, password):
        followFarm = ["the rock", "other_username", "other_username", "kyliejenner", "other_username","other_username", "other_username", "other_username"]
       
        driver = webdriver.Chrome(r"C:\Users\fabio\Desktop\PYHTON\Selenium\chromedriver.exe")

        
        driver.get("https://instagram.com")      
        time.sleep(getRandomTime())
        driver.find_element_by_xpath("//input[@name=\"username\"]")\
            .send_keys(username)
        driver.find_element_by_xpath("//input[@name=\"password\"]")\
            .send_keys(password)
        time.sleep(getRandomTime())      
        driver.find_element_by_xpath('//button[@type="submit"]')\
            .click()

        time.sleep(getRandomTime())
        driver.find_element_by_xpath("//button[contains(text(), 'Non ora')]")\
            .click()
  
        time.sleep(getRandomTime())
        driver.find_element_by_xpath("/html/body/div[4]/div/div/div/div[3]/button[2]")\
            .click()
            
            
        time.sleep(getRandomTime())
        driver.find_element_by_xpath("/html/body/div[1]/section/nav/div[2]/div/div/div[2]/input")\
          .send_keys(followFarm[randint(0, 7)])
    
        time.sleep(getRandomTime())
        driver.find_element_by_xpath("/html/body/div[1]/section/nav/div[2]/div/div/div[2]/div[3]/div[2]/div/a[1]/div")\
            .click()    
      
        time.sleep(getRandomTime())
        driver.find_element_by_xpath("/html/body/div[1]/section/main/div/header/section/ul/li[2]/a").click() 

        time.sleep(getRandomTime())
    
        htmlBadBoyToFollow = "/html/body/div[4]/div/div/div[2]/ul/div/li[2]/div/div[3]/button"   
        for i in range(2,20,1):
             htmlBadBoyToFollow = "/html/body/div[4]/div/div/div[2]/ul/div/li["+str(i)+"]/div/div[3]/button"
        
             if(driver.find_element_by_xpath("/html/body/div[4]/div/div/div[2]/ul/div/li["+str(i)+"]/div/div[3]/button").text == "Following"):
                 # This is so we dont follow people we already follow- trust me this would cause issues otherwise
                 continue               
             driver.find_element_by_xpath(htmlBadBoyToFollow).click()
             time.sleep(getRandomTime())

        driver.quit()

def getRandomTime():
        randTime = randint(3, 5)
        return randTime

  
InstaBot("fabiosketches", "YYY666yyy")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-10-002e47a87960> in <module>
#      60
#      61
# ---> 62 InstaBot("fabiosketches", "YYY666yyy")
#
# <ipython-input-10-002e47a87960> in __init__(self, username, password)
#      26
#      27         time.sleep(getRandomTime())
# ---> 28         driver.find_element_by_xpath("/html/body/div[4]/div/div/div/div[3]/button[2]")\
#      29             .click()
#      30
#
# c:\users\fabio\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...

# %%
# ┌────────────────────────────────────────────────────────────────────────┐
# │ InstaBot - Python Selenium Bot                                         │
# ├────────────────────────────────────────────────────────────────────────┤
# │ Copyright © 2019 Joseph Pereniguez                                     |
# | (https://github.com/Estayparadox/InstaBot)                             │
# ├────────────────────────────────────────────────────────────────────────┤
# │ Licensed under the MIT                                                 |
# | (https://github.com/Estayparadox/InstaBot/blob/master/LICENSE) license.│
# └────────────────────────────────────────────────────────────────────────┘

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep, strftime
from random import randint
import pandas as pd

#for firefoxdriver
# i = __file__.rfind('/')
# webdriver = webdriver.Firefox(executable_path=__file__[:i + 1] + 'geckodriver.exe')
#for chromedriver

webdriver = webdriver.Chrome(r"C:\Users\fabio\Desktop\PYHTON\Selenium\chromedriver.exe")

sleep(1)
webdriver.get('https://www.instagram.com/accounts/login/?source=auth_switcher')
sleep(2)

username = webdriver.find_element_by_name('username')
username.send_keys('fabiosketches') # Change this to your own Instagram username
password = webdriver.find_element_by_name('password')
password.send_keys('YYY666yyy') # Change this to your own Instagram password

button_login = webdriver.find_element_by_xpath('//html//body//div[1]//section//main//div//article//div//div[1]//div//form//div//div[3]//button//div')
button_login.click()
sleep(3)
try:
    notnow = webdriver.find_element_by_xpath('//html//body//div[1]//section//main//div//div//div//div//button')
    notnow.click() # Comment these last 2 lines out, if you don't get a pop up asking about notifications
except :
    pass
hashtag_list = ['trip', 'dronephotography', 'traveler'] # Change this to your own tags

prev_user_list = [] # If it's the first time you run it, use this line and comment the two below
# prev_user_list = pd.read_csv('20190604-224633_users_followed_list.csv', delimiter=',').iloc[:,1:2] # useful to build a user log
# prev_user_list = list(prev_user_list['0'])

new_followed = []
tag = -1
followed = 0
likes = 0
comments = 0

for hashtag in hashtag_list:
    tag += 1
    webdriver.get('https://www.instagram.com/explore/tags/'+ hashtag_list[tag] + '/')
    sleep(5)
    first_thumbnail = webdriver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div')

    first_thumbnail.click()
    sleep(randint(1,2))
    try:
        for x in range(1,200):

            username = webdriver.find_element_by_xpath('/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[1]/h2/a').text
            if username not in prev_user_list:

                # If we already follow, do not unfollow
                if webdriver.find_element_by_xpath('/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[2]/button').text == 'Follow' :

                    webdriver.find_element_by_xpath('/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[2]/button').click()
                    new_followed.append(username)
                    followed += 1

                    # Liking the picture
                    button_like = webdriver.find_element_by_xpath('/html/body/div[3]/div[2]/div/article/div[2]/section[1]/span[1]/button')
                    button_like.click()
                    likes += 1
                    sleep(randint(18,25))

                    # Comments and tracker
                    comm_prob = randint(1,10)
                    print('{}_{}: {}'.format(hashtag, x,comm_prob))
                    if comm_prob > 7:
                        comments += 1
                        webdriver.find_element_by_xpath('/html/body/div[3]/div[2]/div/article/div[2]/section[1]/span[2]/button/span').click()
                        comment_box = webdriver.find_element_by_xpath('/html/body/div[3]/div[2]/div/article/div[2]/section[3]/div/form/textarea')

                        if (comm_prob < 7):
                            comment_box.send_keys('Really cool!')
                            sleep(1)
                        elif (comm_prob > 6) and (comm_prob < 9):
                            comment_box.send_keys('Nice work :)')
                            sleep(1)
                        elif comm_prob == 9:
                            comment_box.send_keys('Nice gallery!!')
                            sleep(1)
                        elif comm_prob == 10:
                            comment_box.send_keys('So cool! :)')
                            sleep(1)
                        # Enter to post comment
                        comment_box.send_keys(Keys.ENTER)
                        sleep(randint(22,28))

                # Next picture
                webdriver.find_element_by_link_text('Next').click()
                sleep(randint(25,29))
            else:
                webdriver.find_element_by_link_text('Next').click()
                sleep(randint(20,26))
    # Some hashtag stops refreshing photos (it may happen sometimes), it continues to the next
    except:
        continue

for n in range(0,len(new_followed)):
    prev_user_list.append(new_followed[n])

updated_user_df = pd.DataFrame(prev_user_list)
updated_user_df.to_csv('{}_users_followed_list.csv'.format(strftime("%Y%m%d-%H%M%S")))
print('Liked {} photos.'.format(likes))
print('Commented {} photos.'.format(comments))
print('Followed {} new people.'.format(followed))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-8-4d1618396d50> in <module>
#      31 password.send_keys('YYY666yyy') # Change this to your own Instagram password
#      32
# ---> 33 button_login = webdriver.find_element_by_xpath('//html//body//div[1]//section//main//div//article//div//div[1]//div//form//div//div[3]//button//div')
#      34 button_login.click()
#      35 sleep(3)
#
# c:\users\fabio\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...
